# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.set_index("Address")
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df2=df1.set_index("Address")

# %%
df2
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df2.loc["735 Dolores St":"1056 Sanchez St","Country":"Employees"]
# Out:
#                 Country         Name  Employees
# Address
# 735 Dolores St      USA  Bready Shop         15
# 332 Hill St         USA  Super River         25
# 3995 23rd St        USA   Ben's Shop         10
# 1056 Sanchez St     USA      Sanchez         12

# %%
df2.iloc[2:5,2:5]
# Out:
#                             State Country         Name
# Address
# 332 Hill St      California 94114     USA  Super River
# 3995 23rd St             CA 94114     USA   Ben's Shop
# 1056 Sanchez St        California     USA      Sanchez

# %%
list(df2.iloc[2:5,2:5])
# Out:
# ['State', 'Country', 'Name']

# %%
df2.ix["1056 Sanchez St",2:5]
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# State      California
# Country           USA
# Name          Sanchez
# Name: 1056 Sanchez St, dtype: object

# %%
df2.drop("735 Dolores St",0)
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df2=df2.drop(df2.index[0:3,])
df2
# Out:
#                  ID       State Country        Name  Employees
# Address
# 3995 23rd St      4    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St   5  California     USA     Sanchez         12
# 551 Alvarado St   6    CA 94114     USA  Richvalley         20

# %%
df2
# Out:
#                  ID       State Country        Name  Employees
# Address
# 3995 23rd St      4    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St   5  California     USA     Sanchez         12
# 551 Alvarado St   6    CA 94114     USA  Richvalley         20

# %%
from geopy.geocoders import Nominatim

# %%
nom=Nominatim(scheme="http")
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\geopy\geocoders\osm.py:138: UserWarning: Using Nominatim with the default "geopy/1.16.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995, 23rd Street, Noe Valley, SF, California, 94114, USA, (37.7529648, -122.4317141, 0.0))

# %%
df4=df1

# %%
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4["Address"]=df4["Address"]+", "+df4["City"]+ ", "+df4["State"]+ ", " + df4["Country"]
df4
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df4["Coordinates"]=df4["Address"].apply(nom.geocode)
df4
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     314         try:
# --> 315             page = requester(req, timeout=timeout, **kwargs)
#     316         except Exception as error:
#
# c:\program files (x86)\python37-32\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# c:\program files (x86)\python37-32\lib\urllib\request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# c:\program files (x86)\python37-32\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
# ...
