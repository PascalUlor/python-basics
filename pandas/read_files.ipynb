# %%
import pandas

# %%
df1=pandas.read_json("supermarkets.json")
df1.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df1.shape
# Out:
# (6, 7)

# %%
df2=pandas.read_csv("sample.csv")
df2
# Out:
#        1115.1
# 0     1126.42
# 1     1126.20
# 2     1127.78
# 3     1126.48
# 4     1120.59
# 5     1118.02
# 6     1114.05
# 7     1102.47
# 8     1096.08
# 9     1109.18
# 10    1107.93
# 11    1114.11
# 12    1106.41
# 13    1102.35
# 14    1095.95
# 15    1091.94
# 16    1103.25
# 17    1105.98
# 18    1099.92
# 19    1109.24
# 20    1108.86
# 21    1095.63
# 22    1091.49
# 23    1110.63
# 24    1105.65
# 25    1106.24
# 26    1091.38
# 27    1094.90
# 28    1109.80
# 29    1110.32
# ...       ...
# 2484  1389.94
# 2485  1387.12
# 2486  1416.83
# 2487  1411.71
# 2488  1441.72
# 2489  1424.24
# 2490  1424.37
# 2491  1424.97
# 2492  1409.12
# 2493  1409.28
# 2494  1394.46
# 2495  1360.16
# 2496  1398.56
# 2497  1404.09
# 2498  1410.03
# 2499  1401.53
# 2500  1441.36
# 2501  1445.57
# 2502  1455.90
# 2503  1455.14
# 2504  1465.15
# 2505  1449.68
# 2506  1432.25
# 2507  1438.56
# 2508  1457.60
# 2509  1441.47
# 2510  1403.45
# 2511  1402.11
# 2512  1399.42
# 2513  1455.22
#
# ...

# %%
df3=pandas.read_excel("hotels.xlsx",sheet_name=0)
df3
# Out:
#                                                                  AUGUST  \
# Volume sold in airline tickets                                    15400
# Total No. of passengers that booked airline tic...                 9103
# Volume sold in hotel room nights (HNN.com)                          259
# # of bookings/ guests for volume sold (complete...                  133
# # of new guests (HNN.com)                                            29
# # of repeat guests (HNN.com)                                         22
# # of Corporate Clients (HNN.com)                                      6
# Volume of room nights by new guests                                  62
# Volume of room nights by repeat guests                              133
# Volume of room nights by Corporate Clients                           64
# # of reps that acquired corporate clients                             3
# Total GMV for all guests (HNN.com)                             11076443
# ...
